# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt

# %%
# !pip install nltk

# %%
#these are for text cleaning before tokenization 
import unicodedata

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text
s = 'Sómě Áccěntěd těxt'
remove_accented_chars(s)

# %%
# contractions 
# !pip install contractions
# !pip install textsearch
s = "Y'all can't expand contractions I'd think! You wouldn't be able to. How'd you do it?"
import contractions

list(contractions.contractions_dict.items())[:10]
print(contractions.fix(s))

# %%
#autocorrect spellings 
from autocorrect import Speller

spell = Speller(lang='en')

print(spell('manegement'))

# %%
gold = """Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).

Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test. Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating. Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.

A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history. In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.

A total of 186,700 tonnes of gold exists above ground, as of 2015.[7] The world consumption of new gold produced is about 50% in jewelry, 40% in investments, and 10% in industry.[8] Gold's high malleability, ductility, resistance to corrosion and most other chemical reactions, and conductivity of electricity have led to its continued use in corrosion resistant electrical connectors in all types of computerized devices (its chief industrial use). Gold is also used in infrared shielding, colored-glass production, gold leafing, and tooth restoration. Certain gold salts are still used as anti-inflammatories in medicine. As of 2016, the world's largest gold producer by far was China with 450 tonnes per year"""

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
txt = "Five o'clock is the time to party!"
txt.split()
# Out:
# ['Five', "o'clock", 'is', 'the', 'time', 'to', 'party!']

# %%
gold_word_tokenize = word_tokenize(gold)

# %%
gold_word_tokenize[:10]
# Out:
# ['Gold', 'is', 'a', 'chemical', 'element', 'with', 'symbol', 'Au', '(', 'from']

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
from nltk.tokenize import wordpunct_tokenize
txt = "This hotel is awesome, isn't it?"
word_tokenize(txt)
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(txt)
# Out:
# ['This', 'hotel', 'is', 'awesome', ',', 'is', "n't", 'it', '?']
# ['This', 'hotel', 'is', 'awesome', ',', 'isn', "'", 't', 'it', '?']

# %%
from nltk.tokenize import TweetTokenizer
txt = "LMAO #killing it , luv mah lyf :D <3"
word_tokenize(txt)
tknzr = TweetTokenizer()
tknzr.tokenize(txt)
# Out:
# ['LMAO', '#', 'killing', 'it', ',', 'luv', 'mah', 'lyf', ':', 'D', '<', '3']
# ['LMAO', '#killing', 'it', ',', 'luv', 'mah', 'lyf', ':D', '<3']

# %%
#from nltk.probability import FreqDist
#fdist = FreqDist(all_terms)
#fdist

# %%
fdist = FreqDist()
fdist = FreqDist(gold_word_tokenize)
fdist
# Out:
# FreqDist({'%': 3,
#           "'s": 2,
#           '(': 5,
#           ')': 5,
#           ',': 39,
#           '.': 18,
#           '10': 1,
#           '11': 1,
#           '186,700': 1,
#           '1930s': 1,
#           '1971': 1,
#           '2015': 1,
#           '2016': 1,
#           '40': 1,
#           '450': 1,
#           '5': 1,
#           '50': 1,
#           '6': 1,
#           '7': 1,
#           '79': 1,
#           '8': 1,
#           ':': 1,
#           'A': 2,
#           'As': 1,
#           'Au': 1,
#           'Certain': 1,
#           'Chemically': 1,
#           'China': 1,
#           'Gold': 8,
#           'In': 2,
#           'It': 2,
#           'Latin': 1,
#           'Less': 1,
#           'The': 1,
#           '[': 4,
#           ']': 4,
#           'a': 14,
#           'abandoned': 1,
#           'about': 1,
#           'above': 1,
#           'acid': 4,
#           'acids': 1,
#           'after': 1,
#           'alkaline': 1,
# ...

# %%
fdist.plot(50,cumulative=False)
plt.show()

# %%
for word in gold_word_tokenize:
    fdist[word.lower()]+=1

# %%
fdist
# Out:
# FreqDist({'%': 6,
#           "'s": 4,
#           '(': 10,
#           ')': 10,
#           ',': 78,
#           '.': 36,
#           '10': 2,
#           '11': 2,
#           '186,700': 2,
#           '1930s': 2,
#           '1971': 2,
#           '2015': 2,
#           '2016': 2,
#           '40': 2,
#           '450': 2,
#           '5': 2,
#           '50': 2,
#           '6': 2,
#           '7': 2,
#           '79': 2,
#           '8': 2,
#           ':': 2,
#           'A': 2,
#           'As': 1,
#           'Au': 1,
#           'Certain': 1,
#           'Chemically': 1,
#           'China': 1,
#           'Gold': 8,
#           'In': 2,
#           'It': 2,
#           'Latin': 1,
#           'Less': 1,
#           'The': 1,
#           '[': 8,
#           ']': 8,
#           'a': 30,
#           'abandoned': 2,
#           'about': 2,
#           'above': 2,
#           'acid': 8,
#           'acids': 2,
#           'after': 2,
#           'alkaline': 2,
# ...

# %%
fdist['in']
# Out:
# 42

# %%
len(fdist)
# Out:
# 236

# %%
fdist_top10=fdist.most_common(20)

# %%
fdist_top10
# Out:
# [(',', 78),
#  ('in', 42),
#  ('.', 36),
#  ('gold', 36),
#  ('and', 34),
#  ('a', 30),
#  ('of', 24),
#  ('is', 22),
#  ('the', 19),
#  ('as', 15),
#  ('to', 14),
#  ('with', 10),
#  ('(', 10),
#  (')', 10),
#  ('it', 10),
#  ('used', 10),
#  ('Gold', 8),
#  ('chemical', 8),
#  ('element', 8),
#  ('acid', 8)]

# %%
from nltk.tokenize import regexp_tokenize, blankline_tokenize

# %%
regexp_tokenize(gold,pattern='\d+')
# Out:
# ['79',
#  '11',
#  '5',
#  '6',
#  '1930',
#  '1971',
#  '186',
#  '700',
#  '2015',
#  '7',
#  '50',
#  '40',
#  '10',
#  '8',
#  '2016',
#  '450']

# %%
regexp_tokenize(gold,pattern='[\w]+')
# Out:
# ['Gold',
#  'is',
#  'a',
#  'chemical',
#  'element',
#  'with',
#  'symbol',
#  'Au',
#  'from',
#  'Latin',
#  'aurum',
#  'and',
#  'atomic',
#  'number',
#  '79',
#  'making',
#  'it',
#  'one',
#  'of',
#  'the',
#  'higher',
#  'atomic',
#  'number',
#  'elements',
#  'that',
#  'occur',
#  'naturally',
#  'In',
#  'its',
#  'purest',
#  'form',
#  'it',
#  'is',
#  'a',
#  'bright',
#  'slightly',
#  'reddish',
#  'yellow',
#  'dense',
#  'soft',
#  'malleable',
#  'and',
#  'ductile',
#  'metal',
#  'Chemically',
#  'gold',
#  'is',
#  'a',
#  'transition',
#  'metal',
#  'and',
#  'a',
#  'group',
#  '11',
#  'element',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  'least',
#  'reactive',
#  'chemical',
#  'elements',
#  'and',
#  'is',
#  'solid',
#  'under',
#  'standard',
#  'conditions',
#  'Gold',
#  'often',
#  'occurs',
#  'in',
#  'free',
#  'elemental',
#  'native',
#  'form',
#  'as',
#  'nuggets',
#  'or',
#  'grains',
#  'in',
#  'rocks',
#  'in',
# ...

# %%
message = "Living life king size #lifegoals #chilling #wanderlust #yolo"
pattern = "#[\w]+"
regexp_tokenize(message,pattern)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a5237fe62402> in <module>()
#       1 message = "Living life king size #lifegoals #chilling #wanderlust #yolo"
#       2 pattern = "#[\w]+"
# ----> 3 regexp_tokenize(message,pattern)
#
# NameError: name 'regexp_tokenize' is not defined

# %%
gold_bl_tokenize=blankline_tokenize(gold)

# %%
len(gold_bl_tokenize)
# Out:
# 4

# %%
gold_bl_tokenize[1]
# Out:
# 'Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test. Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating. Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.'

# %%
from nltk.tokenize import sent_tokenize

# %%
gold_sent_tokenize=sent_tokenize(gold)

# %%
gold_sent_tokenize
# Out:
# ['Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally.',
#  'In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal.',
#  'Chemically, gold is a transition metal and a group 11 element.',
#  'It is one of the least reactive chemical elements and is solid under standard conditions.',
#  'Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits.',
#  'It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium.',
#  'Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).',
#  'Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion.',
# ...

# %%
! pip install langdetect
# Out:
# ...
#      |████████████████████████████████| 983kB 2.8MB/s
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993193 sha256=375a0fcda0eba8d16d4eabf6c14466fd5d64f6fe6f80839d8d017d938015830f
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
# Successfully built langdetect
# ...

# %%
from langdetect import detect
detect("War doesn't show who's right, just who's left.Ein, zwei, drei, vier")
#detect("Ein, zwei, drei, vier")
# Out:
# 'en'

# %%
text= "A special court here Saturday granted conditional bail to BJD candidate and sitting MLA Pradeep Maharathy who was arrested on the charge of attacking a magistrate of the Election Commission's flying squad. The court granted bail to the MLA on a surety of Rs 50,000 with a condition not to influence the witnesses, government pleader Pradipta Kumar Mishra said. The court also directed him to cooperate with police in the investigation. Earlier, police had submitted the case diary and injury report in the court. The Pipili candidate's plea was slated to be heard on Wednesday but it was deferred due to delay in submission of case diary and injury report. Maharathy, who is presently admitted to the Capital Hospital under judicial custody, was arrested on April 22 for attacking the EC's flying squad, including its magistrate, on the night of April 21"

# %%
reviews_tokens = [word_tokenize(x) for x in text]
reviews_tokens[2]
# Out:
# ['s']

# %%
reviews_tokens
# Out:
# [['A'],
#  [],
#  ['s'],
#  ['p'],
#  ['e'],
#  ['c'],
#  ['i'],
#  ['a'],
#  ['l'],
#  [],
#  ['c'],
#  ['o'],
#  ['u'],
#  ['r'],
#  ['t'],
#  [],
#  ['h'],
#  ['e'],
#  ['r'],
#  ['e'],
#  [],
#  ['S'],
#  ['a'],
#  ['t'],
#  ['u'],
#  ['r'],
#  ['d'],
#  ['a'],
#  ['y'],
#  [],
#  ['g'],
#  ['r'],
#  ['a'],
#  ['n'],
#  ['t'],
#  ['e'],
#  ['d'],
#  [],
#  ['c'],
#  ['o'],
#  ['n'],
#  ['d'],
#  ['i'],
#  ['t'],
#  ['i'],
#  ['o'],
#  ['n'],
#  ['a'],
#  ['l'],
#  [],
#  ['b'],
#  ['a'],
#  ['i'],
#  ['l'],
#  [],
#  ['t'],
#  ['o'],
#  [],
#  ['B'],
#  ['J'],
#  ['D'],
#  [],
#  ['c'],
#  ['a'],
#  ['n'],
#  ['d'],
#  ['i'],
#  ['d'],
#  ['a'],
#  ['t'],
#  ['e'],
#  [],
#  ['a'],
#  ['n'],
#  ['d'],
#  [],
#  ['s'],
#  ['i'],
#  ['t'],
#  ['t'],
#  ['i'],
#  ['n'],
#  ['g'],
#  [],
#  ['M'],
#  ['L'],
#  ['A'],
#  [],
#  ['P'],
#  ['r'],
#  ['a'],
#  ['d'],
#  ['e'],
#  ['e'],
#  ['p'],
#  [],
#  ['M'],
#  ['a'],
#  ['h'],
#  ['a'],
#  ['r'],
#  ['a'],
#  ['t'],
#  ['h'],
# ...

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
string = "The Mona Lisa is a half length portrait painting by the Italian Renaissance artist Leonardo da Vinci"

# %%
# !pip install punkt
# Out:
# ERROR: Could not find a version that satisfies the requirement punkt (from versions: none)
# ERROR: No matching distribution found for punkt

# %%
mona_lisa_tokens=nltk.word_tokenize(string)

# %%
mona_lisa_tokens
# Out:
# ['The',
#  'Mona',
#  'Lisa',
#  'is',
#  'a',
#  'half',
#  'length',
#  'portrait',
#  'painting',
#  'by',
#  'the',
#  'Italian',
#  'Renaissance',
#  'artist',
#  'Leonardo',
#  'da',
#  'Vinci']

# %%
mona_lisa_bigrams=list(nltk.bigrams(mona_lisa_tokens))

# %%
mona_lisa_ngrams=list(nltk.ngrams(mona_lisa_tokens,10))

# %%
len(mona_lisa_ngrams)
# Out:
# 8

# %%
mona_lisa_trigrams=list(nltk.trigrams(mona_lisa_tokens))

# %%
mona_lisa_trigrams
# Out:
# [('The', 'Mona', 'Lisa'),
#  ('Mona', 'Lisa', 'is'),
#  ('Lisa', 'is', 'a'),
#  ('is', 'a', 'half'),
#  ('a', 'half', 'length'),
#  ('half', 'length', 'portrait'),
#  ('length', 'portrait', 'painting'),
#  ('portrait', 'painting', 'by'),
#  ('painting', 'by', 'the'),
#  ('by', 'the', 'Italian'),
#  ('the', 'Italian', 'Renaissance'),
#  ('Italian', 'Renaissance', 'artist'),
#  ('Renaissance', 'artist', 'Leonardo'),
#  ('artist', 'Leonardo', 'da'),
#  ('Leonardo', 'da', 'Vinci')]

# %%
mona_lisa_ngrams=list(nltk.ngrams(mona_lisa_tokens, 4))

# %%
mona_lisa_ngrams
# Out:
# [('The', 'Mona', 'Lisa', 'is'),
#  ('Mona', 'Lisa', 'is', 'a'),
#  ('Lisa', 'is', 'a', 'half'),
#  ('is', 'a', 'half', 'length'),
#  ('a', 'half', 'length', 'portrait'),
#  ('half', 'length', 'portrait', 'painting'),
#  ('length', 'portrait', 'painting', 'by'),
#  ('portrait', 'painting', 'by', 'the'),
#  ('painting', 'by', 'the', 'Italian'),
#  ('by', 'the', 'Italian', 'Renaissance'),
#  ('the', 'Italian', 'Renaissance', 'artist'),
#  ('Italian', 'Renaissance', 'artist', 'Leonardo'),
#  ('Renaissance', 'artist', 'Leonardo', 'da'),
#  ('artist', 'Leonardo', 'da', 'Vinci')]

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

# %%
pst=PorterStemmer()

# %%
pst.stem("having")
# Out:
# 'have'

# %%
pst.stem("giving")
# Out:
# 'give'

# %%
words_to_stem=["give","giving","given","gave"]

# %%
for words in words_to_stem:
    print(words+ ":" +pst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %%
lst=LancasterStemmer()

# %%
#the words looses its meaning with stemming 
for words in words_to_stem:
    print(words+ ":" +lst.stem(words))
# Out:
# give:giv
# giving:giv
# given:giv
# gave:gav

# %%
sbst=SnowballStemmer('english')

# %%
sbst.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
sbst.stem('having')
# Out:
# 'have'

# %%
for words in words_to_stem:
    print(words+ ":" +sbst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %%
def stemms(word):
    print("Porter:"+pst.stem(word))
    print("Lancaster:"+lst.stem(word))
    print("Snowball:"+sbst.stem(word))
    return

# %%
stemms('taking')
# Out:
# Porter:take
# Lancaster:tak
# Snowball:take

# %%
stemms('data')
# Out:
# Porter:data
# Lancaster:dat
# Snowball:data

# %%
stemms('corpus')
# Out:
# Porter:corpu
# Lancaster:corp
# Snowball:corpus

# %%
stemms('curricula')
# Out:
# Porter:curricula
# Lancaster:curricul
# Snowball:curricula

# %%
stemms('curriculum')
# Out:
# Porter:curriculum
# Lancaster:curricul
# Snowball:curriculum

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

# %%
word_lem=WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
word_lem.lemmatize('corpora')
# Out:
# 'corpus'

# %%
word_lem.lemmatize('curricula')
# Out:
# 'curriculum'

# %%
for words in words_to_stem:
    print(words+ ":" +word_lem.lemmatize(words))
# Out:
# give:give
# giving:giving
# given:given
# gave:gave

# %%
for words in words_to_stem:
    print(words+ ":" +word_lem.lemmatize(words,wordnet.NOUN))
# Out:
# give:give
# giving:giving
# given:given
# gave:gave

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
fdist_top10
# Out:
# [(',', 78),
#  ('in', 42),
#  ('.', 36),
#  ('gold', 36),
#  ('and', 34),
#  ('a', 30),
#  ('of', 24),
#  ('is', 22),
#  ('the', 19),
#  ('as', 15),
#  ('to', 14),
#  ('with', 10),
#  ('(', 10),
#  (')', 10),
#  ('it', 10),
#  ('used', 10),
#  ('Gold', 8),
#  ('chemical', 8),
#  ('element', 8),
#  ('acid', 8)]

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
punctuation=re.compile(r'[-.?!,:;()|0-9]')

# %%
post_punctuation=[]

# %%
gold_word_tokenize[:2]
# Out:
# ['Gold', 'is']

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
gold_word_tokenize[:10]
# Out:
# ['Gold', 'is', 'a', 'chemical', 'element', 'with', 'symbol', 'Au', '(', 'from']

# %%
for words in gold_word_tokenize:
    word=punctuation.sub("",words)
    if len(word)>0:
        post_punctuation.append(word)

# %%
len(post_punctuation) #list after removing punctuation
# Out:
# 397

# %%
post_stop_words=[]

# %%
stp_words=stopwords.words('english')
stp_words[:10]
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
post_punctuation[:10]
# Out:
# ['Gold',
#  'is',
#  'a',
#  'chemical',
#  'element',
#  'with',
#  'symbol',
#  'Au',
#  'from',
#  'Latin']

# %%
for words in post_punctuation:
    words=words.lower()
    if words not in stp_words:
        post_stop_words.append(words)

# %%
len(post_stop_words)
# Out:
# 243

# %%
fdist2=FreqDist()

# %%
for word in post_stop_words:
    fdist2[word]+=1

# %%
len(fdist2)
# Out:
# 170

# %%
fdist_top10
# Out:
# [(',', 78),
#  ('in', 42),
#  ('.', 36),
#  ('gold', 36),
#  ('and', 34),
#  ('a', 30),
#  ('of', 24),
#  ('is', 22),
#  ('the', 19),
#  ('as', 15),
#  ('to', 14),
#  ('with', 10),
#  ('(', 10),
#  (')', 10),
#  ('it', 10),
#  ('used', 10),
#  ('Gold', 8),
#  ('chemical', 8),
#  ('element', 8),
#  ('acid', 8)]

# %%
fdist2.most_common(10)
# Out:
# [('gold', 22),
#  ('used', 5),
#  ('chemical', 4),
#  ('element', 4),
#  ('acid', 4),
#  ('[', 4),
#  (']', 4),
#  ('metal', 3),
#  ('standard', 3),
#  ('often', 3)]

# %%
fdist.most_common(10)
# Out:
# [(',', 78),
#  ('in', 42),
#  ('.', 36),
#  ('gold', 36),
#  ('and', 34),
#  ('a', 30),
#  ('of', 24),
#  ('is', 22),
#  ('the', 19),
#  ('as', 15)]

# %%
fdist = FreqDist()
fdist = FreqDist(post_stop_words)
fdist
# Out:
# FreqDist({'%': 3,
#           "'s": 2,
#           '[': 4,
#           ']': 4,
#           'abandoned': 1,
#           'acid': 4,
#           'acids': 1,
#           'alkaline': 1,
#           'alloyed': 1,
#           'alloys': 1,
#           'alluvial': 1,
#           'also': 3,
#           'amalgam': 1,
#           'anion': 1,
#           'antiinflammatories': 1,
#           'aqua': 1,
#           'arts': 1,
#           'atomic': 2,
#           'au': 1,
#           'aurum': 1,
#           'base': 1,
#           'bright': 1,
#           'ceased': 1,
#           'certain': 1,
#           'chemical': 4,
#           'chemically': 1,
#           'chief': 1,
#           'china': 1,
#           'circulating': 1,
#           'coinage': 1,
#           'coins': 1,
#           'coloredglass': 1,
#           'commonly': 1,
#           'compounds': 1,
#           'computerized': 1,
#           'conditions': 1,
#           'conductivity': 1,
#           'confirm': 1,
# ...

# %%
fdist.plot(30,cumulative=False)
plt.show()

# %%
import unicodedata

def remove_accented_chars(text):
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text
s = 'Sómě Áccěntěd těxt'
remove_accented_chars(s)
# Out:
# 'Some Accented text'

# %%
# !pip install contractions
# !pip install textsearch
s = "Y'all can't expand contractions I'd think! You wouldn't be able to. How'd you do it?"
import contractions

list(contractions.contractions_dict.items())[:10]
print(contractions.fix(s))
# Out:
# ...
# [("ain't", 'are not'),
#  ("aren't", 'are not'),
#  ("can't", 'can not'),
#  ("can't've", 'can not have'),
#  ("'cause", 'because'),
#  ("could've", 'could have'),
#  ("couldn't", 'could not'),
#  ("couldn't've", 'could not have'),
#  ("didn't", 'did not'),
#  ("doesn't", 'does not')]
# you all can not expand contractions I would think! You would not be able to. how did you do it?

# %%
# !pip install autocorrect
# Out:
# ...
#      |████████████████████████████████| 1.8MB 2.8MB/s
# ...
#   Created wheel for autocorrect: filename=autocorrect-2.0.0-cp36-none-any.whl size=1811641 sha256=2fca6079db09f6590f0cd101cb60ce4fe23f6665d3b0cae68b2281366e1c75a5
#   Stored in directory: /root/.cache/pip/wheels/0b/06/bc/e66f28d72bed29591eadc79cebb2e7964ad0282804ab233da3
# Successfully built autocorrect
# ...

# %%
from autocorrect import Speller

spell = Speller(lang='en')

print(spell('manegement'))
# Out:
# management

# %%
mona_lisa_ngrams_stopwrods=list(nltk.ngrams(post_stop_words, 2))
mona_lisa_ngrams_stopwrods
# Out:
# [('gold', 'chemical'),
#  ('chemical', 'element'),
#  ('element', 'symbol'),
#  ('symbol', 'au'),
#  ('au', 'latin'),
#  ('latin', 'aurum'),
#  ('aurum', 'atomic'),
#  ('atomic', 'number'),
#  ('number', 'making'),
#  ('making', 'one'),
#  ('one', 'higher'),
#  ('higher', 'atomic'),
#  ('atomic', 'number'),
#  ('number', 'elements'),
#  ('elements', 'occur'),
#  ('occur', 'naturally'),
#  ('naturally', 'purest'),
#  ('purest', 'form'),
#  ('form', 'bright'),
#  ('bright', 'slightly'),
#  ('slightly', 'reddish'),
#  ('reddish', 'yellow'),
#  ('yellow', 'dense'),
#  ('dense', 'soft'),
#  ('soft', 'malleable'),
#  ('malleable', 'ductile'),
#  ('ductile', 'metal'),
#  ('metal', 'chemically'),
#  ('chemically', 'gold'),
#  ('gold', 'transition'),
#  ('transition', 'metal'),
#  ('metal', 'group'),
#  ('group', 'element'),
#  ('element', 'one'),
#  ('one', 'least'),
#  ('least', 'reactive'),
#  ('reactive', 'chemical'),
#  ('chemical', 'elements'),
#  ('elements', 'solid'),
# ...

# %%
import nltk
from nltk.util import ngrams
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

word_fd = nltk.FreqDist(post_stop_words)
bigram_fd = nltk.FreqDist(nltk.bigrams(post_stop_words))

bigram_fd.most_common()
# Out:
# [(('[', ']'), 4),
#  (('atomic', 'number'), 2),
#  (('nitric', 'acid'), 2),
#  (('gold', 'also'), 2),
#  ((']', 'gold'), 2),
#  (('gold', 'standard'), 2),
#  (('gold', 'chemical'), 1),
#  (('chemical', 'element'), 1),
#  (('element', 'symbol'), 1),
#  (('symbol', 'au'), 1),
#  (('au', 'latin'), 1),
#  (('latin', 'aurum'), 1),
#  (('aurum', 'atomic'), 1),
#  (('number', 'making'), 1),
#  (('making', 'one'), 1),
#  (('one', 'higher'), 1),
#  (('higher', 'atomic'), 1),
#  (('number', 'elements'), 1),
#  (('elements', 'occur'), 1),
#  (('occur', 'naturally'), 1),
#  (('naturally', 'purest'), 1),
#  (('purest', 'form'), 1),
#  (('form', 'bright'), 1),
#  (('bright', 'slightly'), 1),
#  (('slightly', 'reddish'), 1),
#  (('reddish', 'yellow'), 1),
#  (('yellow', 'dense'), 1),
#  (('dense', 'soft'), 1),
#  (('soft', 'malleable'), 1),
#  (('malleable', 'ductile'), 1),
#  (('ductile', 'metal'), 1),
#  (('metal', 'chemically'), 1),
#  (('chemically', 'gold'), 1),
# ...

# %%
#compute frequency distribution for all the bigrams in the text
fdist = nltk.FreqDist(mona_lisa_ngrams_stopwrods)
for k,v in fdist.items():
    print(k,v)
# Out:
# ('gold', 'chemical') 1
# ('chemical', 'element') 1
# ('element', 'symbol') 1
# ('symbol', 'au') 1
# ('au', 'latin') 1
# ('latin', 'aurum') 1
# ('aurum', 'atomic') 1
# ('atomic', 'number') 2
# ('number', 'making') 1
# ('making', 'one') 1
# ('one', 'higher') 1
# ('higher', 'atomic') 1
# ('number', 'elements') 1
# ('elements', 'occur') 1
# ('occur', 'naturally') 1
# ('naturally', 'purest') 1
# ('purest', 'form') 1
# ('form', 'bright') 1
# ('bright', 'slightly') 1
# ('slightly', 'reddish') 1
# ('reddish', 'yellow') 1
# ('yellow', 'dense') 1
# ('dense', 'soft') 1
# ('soft', 'malleable') 1
# ('malleable', 'ductile') 1
# ('ductile', 'metal') 1
# ('metal', 'chemically') 1
# ('chemically', 'gold') 1
# ('gold', 'transition') 1
# ('transition', 'metal') 1
# ('metal', 'group') 1
# ('group', 'element') 1
# ('element', 'one') 1
# ('one', 'least') 1
# ('least', 'reactive') 1
# ('reactive', 'chemical') 1
# ('chemical', 'elements') 1
# ('elements', 'solid') 1
# ('solid', 'standard') 1
# ...

# %%
# !pip install WordCloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize']=(20.0,20.0)    #(6.0,4.0)
mpl.rcParams['font.size']=12                #10 
mpl.rcParams['savefig.dpi']=100             #72 
mpl.rcParams['figure.subplot.bottom']=.1 


stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='white',
                          stopwords=stopwords,
                          max_words=200,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(post_stop_words))

print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)
# Out:
# ...
# (-0.5, 399.5, 199.5, -0.5)

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text="Barack Obama did not think Joseph R. Biden Jr. should run for president — he hardly needed to say it out loud for aides to understand that. The trick that summer of 2015 was finding a way to nudge Mr. Biden to stay out of the race without looking as if he was nudging Mr. Biden to stay out of the race."
token=word_tokenize(text)
for words in token:
     print(nltk.pos_tag([words]))
# Out:
# [('Barack', 'NN')]
# [('Obama', 'NN')]
# [('did', 'VBD')]
# [('not', 'RB')]
# [('think', 'NN')]
# [('Joseph', 'NNP')]
# [('R.', 'NNP')]
# [('Biden', 'NNP')]
# [('Jr.', 'NNP')]
# [('should', 'MD')]
# [('run', 'VB')]
# [('for', 'IN')]
# [('president', 'NN')]
# [('—', 'NN')]
# [('he', 'PRP')]
# [('hardly', 'RB')]
# [('needed', 'VBN')]
# [('to', 'TO')]
# [('say', 'VB')]
# [('it', 'PRP')]
# [('out', 'IN')]
# [('loud', 'NN')]
# [('for', 'IN')]
# [('aides', 'NNS')]
# [('to', 'TO')]
# [('understand', 'NN')]
# [('that', 'IN')]
# [('.', '.')]
# [('The', 'DT')]
# [('trick', 'NN')]
# [('that', 'IN')]
# [('summer', 'NN')]
# [('of', 'IN')]
# [('2015', 'CD')]
# [('was', 'VBD')]
# [('finding', 'VBG')]
# [('a', 'DT')]
# [('way', 'NN')]
# [('to', 'TO')]
# [('nudge', 'NN')]
# [('Mr.', 'NNP')]
# [('Biden', 'NNP')]
# [('to', 'TO')]
# [('stay', 'NN')]
# [('out', 'IN')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('race', 'NN')]
# [('without', 'IN')]
# [('looking', 'VBG')]
# [('as', 'IN')]
# [('if', 'IN')]
# ...

# %%
text="john eats a banana"
token=word_tokenize(text)
for words in token:
     print(nltk.pos_tag([words]))
# Out:
# [('john', 'NN')]
# [('eats', 'NNS')]
# [('a', 'DT')]
# [('banana', 'NN')]

# %%
words
# Out:
# 'banana'

# %%
token
# Out:
# ['john', 'eats', 'a', 'banana']

# %%
nltk.pos_tag(token)
# Out:
# [('john', 'NN'), ('eats', 'VBZ'), ('a', 'DT'), ('banana', 'NN')]

# %%
reg_token=regexp_tokenize(text,'[\w]+')

# %%
reg_token
# Out:
# ['john', 'eats', 'a', 'banana']

# %%
nltk.pos_tag(reg_token)
# Out:
# [('john', 'NN'), ('eats', 'VBZ'), ('a', 'DT'), ('banana', 'NN')]

# %%
from nltk import ne_chunk

# %%
NE_sent="Bahujan Samaj Party chief Mayawati on Saturday hit back at Prime Minister Narendra Modi, claiming that he included his caste in the list Other Backward Class (OBC) communities for political gains. The comments came soon after PM Modi accused the opposition of thinking of him as a neech (lowly) person .Accusing PM Modi of including his caste in the list of backwards during his term as the Gujarat chief minister, Mayawati said at a press conference in Lucknow,In order to derive political profits during elections, he (PM Modi) got his upper caste included in the list of backward castes. Like Mulayam Singh Yadav and Akhilesh Yadav, (PM) Modi was not born in a backward caste."

# %%
token=word_tokenize(NE_sent)
NE_tag=nltk.pos_tag(token)

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
NE_tag
# Out:
# [('Bahujan', 'NNP'),
#  ('Samaj', 'NNP'),
#  ('Party', 'NNP'),
#  ('chief', 'JJ'),
#  ('Mayawati', 'NNP'),
#  ('on', 'IN'),
#  ('Saturday', 'NNP'),
#  ('hit', 'VBD'),
#  ('back', 'RB'),
#  ('at', 'IN'),
#  ('Prime', 'NNP'),
#  ('Minister', 'NNP'),
#  ('Narendra', 'NNP'),
#  ('Modi', 'NNP'),
#  (',', ','),
#  ('claiming', 'VBG'),
#  ('that', 'IN'),
#  ('he', 'PRP'),
#  ('included', 'VBD'),
#  ('his', 'PRP$'),
#  ('caste', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('list', 'NN'),
#  ('Other', 'JJ'),
#  ('Backward', 'NNP'),
#  ('Class', 'NNP'),
#  ('(', '('),
#  ('OBC', 'NNP'),
#  (')', ')'),
#  ('communities', 'NNS'),
#  ('for', 'IN'),
#  ('political', 'JJ'),
#  ('gains', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('comments', 'NNS'),
#  ('came', 'VBD'),
#  ('soon', 'RB'),
#  ('after', 'IN'),
#  ('PM', 'NNP'),
#  ('Modi', 'NNP'),
#  ('accused', 'VBD'),
#  ('the', 'DT'),
#  ('opposition', 'NN'),
#  ('of', 'IN'),
#  ('thinking', 'NN'),
#  ('of', 'IN'),
#  ('him', 'PRP'),
# ...

# %%
ner=ne_chunk(NE_tag)
print(ner)
# Out:
# (S
#   (PERSON Bahujan/NNP)
#   (PERSON Samaj/NNP Party/NNP)
#   chief/JJ
#   Mayawati/NNP
#   on/IN
#   Saturday/NNP
#   hit/VBD
#   back/RB
#   at/IN
#   Prime/NNP
#   Minister/NNP
#   (PERSON Narendra/NNP Modi/NNP)
#   ,/,
#   claiming/VBG
#   that/IN
#   he/PRP
#   included/VBD
#   his/PRP$
#   caste/NN
#   in/IN
#   the/DT
#   list/NN
#   Other/JJ
#   (ORGANIZATION Backward/NNP)
#   Class/NNP
#   (/(
#   (ORGANIZATION OBC/NNP)
#   )/)
#   communities/NNS
#   for/IN
#   political/JJ
#   gains/NNS
#   ./.
#   The/DT
#   comments/NNS
#   came/VBD
#   soon/RB
#   after/IN
#   (ORGANIZATION PM/NNP Modi/NNP)
#   accused/VBD
#   the/DT
#   opposition/NN
#   of/IN
#   thinking/NN
#   of/IN
#   him/PRP
#   as/IN
#   a/DT
#   neech/NN
#   (/(
#   lowly/RB
#   )/)
#   person/NN
#   .Accusing/VBG
#   (ORGANIZATION PM/NNP Modi/NNP)
#   of/IN
#   including/VBG
#   his/PRP$
#   caste/NN
#   in/IN
#   the/DT
#   list/NN
#   of/IN
#   backwards/NNS
#   during/IN
#   his/PRP$
#   term/NN
# ...

# %%
import re

text = """Three more countries have joined an “international grand committee” of parliaments, adding to calls for 
Facebook’s boss, Mark Zuckerberg, to give evidence on misinformation to the coalition. Brazil, Latvia and Singapore 
bring the total to eight different parliaments across the world, with plans to send representatives to London on 27 
November with the intention of hearing from Zuckerberg. Since the Cambridge Analytica scandal broke, the Facebook chief 
has only appeared in front of two legislatures: the American Senate and House of Representatives, and the European parliament. 
Facebook has consistently rebuffed attempts from others, including the UK and Canadian parliaments, to hear from Zuckerberg. 
He added that an article in the New York Times on Thursday, in which the paper alleged a pattern of behaviour from Facebook 
to “delay, deny and deflect” negative news stories, “raises further questions about how recent data breaches were allegedly 
dealt with within Facebook.”
"""

text = re.sub(r'\n', '', text)
text
# Out:
# 'Three more countries have joined an “international grand committee” of parliaments, adding to calls for Facebook’s boss, Mark Zuckerberg, to give evidence on misinformation to the coalition. Brazil, Latvia and Singapore bring the total to eight different parliaments across the world, with plans to send representatives to London on 27 November with the intention of hearing from Zuckerberg. Since the Cambridge Analytica scandal broke, the Facebook chief has only appeared in front of two legislatures: the American Senate and House of Representatives, and the European parliament. Facebook has consistently rebuffed attempts from others, including the UK and Canadian parliaments, to hear from Zuckerberg. He added that an article in the New York Times on Thursday, in which the paper alleged a pattern of behaviour from Facebook to “delay, deny and deflect” negative news stories, “raises further questions about how recent data breaches were allegedly dealt with within Facebook.”'

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en')
text_nlp = nlp(text)
displacy.render(text_nlp, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Three
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more countries have joined an “international grand committee” of parliaments, adding to calls for Facebook’s boss,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark Zuckerberg
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , to give evidence on misinformation to the coalition.
# ...
